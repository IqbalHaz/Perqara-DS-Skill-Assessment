# %% [markdown]
# # A Look into Order Reviews Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../datasets/order_reviews_dataset.csv')
df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Data Description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# There is a significant number of missing values in `review_comment_title` and `review_comment_message`.

# %%
df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
df.describe(include=[object])
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     4548534449b1f572e357211b90724f1b  03c939fd7fd3b38f8485a0f95798f1f6
# freq                                   3                                 3
#
#        review_comment_title review_comment_message review_creation_date  \
# count                 11568                  40977                99224
# unique                 4527                  36159                  636
# top               Recomendo              Muito bom  2017-12-19 00:00:00
# freq                    423                    230                  463
#
#        review_answer_timestamp
# count                    99224
# unique                   98248
# top        2017-06-15 23:21:05
# freq                         4

# %% [markdown]
# ### Review Score Count

# %%
review_count = df.review_score.value_counts().reset_index(name='counts').sort_values(by='review_score')
review_count
# Out:
#    review_score  counts
# 2             1   11424
# 4             2    3151
# 3             3    8179
# 1             4   19142
# 0             5   57328

# %%
fig, ax = plt.subplots()

scores = review_count.review_score.to_numpy()
y_pos = np.arange(len(scores))
counts = review_count.counts.to_numpy()

ax.barh(y_pos, counts, align='center')
ax.set_yticks(y_pos, labels=scores)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('No. of Review')
ax.set_title('Each Review Score Count')

plt.show()
