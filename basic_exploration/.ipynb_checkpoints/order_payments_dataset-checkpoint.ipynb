# %% [markdown]
# # A Look into Order Payments Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../datasets/order_payments_dataset.csv')
df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Data Description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# As can be seen above, no missing value from `order_payments_dataset`.

# %%
df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
df.describe(include=[object])
# Out:
#                                 order_id payment_type
# count                             103886       103886
# unique                             99440            5
# top     fa65dad1b0e818e3ccc5cb0e39231352  credit_card
# freq                                  29        76795

# %% [markdown]
# ### Payment Value Distribution

# %%
plt.hist(df.payment_value, bins=20)
plt.title('payment value')
plt.show()

# %% [markdown]
# ### Payment Sequential Count

# %%
df.payment_sequential.value_counts().reset_index(name='counts')
# Out:
#     payment_sequential  counts
# 0                    1   99360
# 1                    2    3039
# 2                    3     581
# 3                    4     278
# 4                    5     170
# 5                    6     118
# 6                    7      82
# 7                    8      54
# 8                    9      43
# 9                   10      34
# 10                  11      29
# 11                  12      21
# 12                  13      13
# 13                  14      10
# 14                  15       8
# 15                  17       6
# 16                  19       6
# 17                  18       6
# 18                  16       6
# 19                  20       4
# 20                  21       4
# 21                  22       3
# 22                  24       2
# 23                  25       2
# 24                  26       2
# 25                  23       2
# 26                  27       1
# 27                  28       1
# 28                  29       1

# %% [markdown]
# ### Payment Installments Count

# %%
df.payment_installments.value_counts().reset_index(name='counts')
# Out:
#     payment_installments  counts
# 0                      1   52546
# 1                      2   12413
# 2                      3   10461
# 3                      4    7098
# 4                     10    5328
# 5                      5    5239
# 6                      8    4268
# 7                      6    3920
# 8                      7    1626
# 9                      9     644
# 10                    12     133
# 11                    15      74
# 12                    18      27
# 13                    11      23
# 14                    24      18
# 15                    20      17
# 16                    13      16
# 17                    14      15
# 18                    17       8
# 19                    16       5
# 20                    21       3
# 21                     0       2
# 22                    22       1
# 23                    23       1

# %% [markdown]
# ### Payment Type Count

# %%
payment_count = df.payment_type.value_counts().reset_index(name='counts')
payment_count
# Out:
#   payment_type  counts
# 0  credit_card   76795
# 1       boleto   19784
# 2      voucher    5775
# 3   debit_card    1529
# 4  not_defined       3

# %%
fig, ax = plt.subplots()

types = payment_count.payment_type.to_numpy()
y_pos = np.arange(len(types))
counts = payment_count.counts.to_numpy()

ax.barh(y_pos, counts, align='center')
ax.set_yticks(y_pos, labels=types)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('No. of Customer using certain Payment Type')
ax.set_title('Each Payment Type Count')

plt.show()
